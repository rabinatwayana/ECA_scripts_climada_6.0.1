# %%
# CLIMADA 6.0.1 Installation and Environment Setup for Google Colab

# =============================================================================
# STEP 1: Install CLIMADA using mamba
# =============================================================================

#Pandas is giving an issue, so installing the save version of the pandas used in climada
# !pip install pandas==2.1.4 fiona==1.10.1 --force-reinstall --no-cache-dir

#Note: Restart the session after running this cell
# Out:
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting fiona==1.10.1
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 7.5 MB/s eta 0:00:00
# Collecting numpy<2,>=1.23.2 (from pandas==2.1.4)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 123.3 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2 (from pandas==2.1.4)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.1.4)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.1.4)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting attrs>=19.2.0 (from fiona==1.10.1)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from fiona==1.10.1)
#   Downloading certifi-2025.7.9-py3-none-any.whl.metadata (2.4 kB)
# Collecting click~=8.0 (from fiona==1.10.1)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting click-plugins>=1.0 (from fiona==1.10.1)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona==1.10.1)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.1.4)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 153.6 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 184.8 MB/s eta 0:00:00
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 162.8 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 168.3 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 166.3 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 197.9 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 205.9 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 21.8 MB/s eta 0:00:00
# Downloading certifi-2025.7.9-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 181.5 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, numpy, click, certifi, attrs, python-dateutil, cligj, click-plugins, pandas, fiona
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.7.9
#     Uninstalling certifi-2025.7.9:
#       Successfully uninstalled certifi-2025.7.9
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.6 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed attrs-25.3.0 certifi-2025.7.9 click-8.2.1 click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1 numpy-1.26.4 pandas-2.1.4 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
#Installing condacolab to setup and manage conda environment in colab
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
#Installing climada package
# !mamba install -y -c conda-forge climada==6.0.1

# Checking if proj database file "proj.db" is available in /usr/local/share/proj. Normally, it should be available.
# !ls /usr/local/share/proj/proj.db

'''
Setting up the environment path so that the packages like pyproj, rasterio, and fiona
could locate the proj.db without any error/conflict (CRSError: Missing projection database)
'''

import os
os.environ['PROJ_LIB'] = '/usr/local/share/proj'

print("✓ CLIMADA 6.0.1 installed using official requirements")

# =============================================================================
# STEP 2: Verification and Testing
# =============================================================================

# Test CLIMADA installation
import sys
print("Python version:", sys.version)
print("\n" + "="*50)
print("TESTING CLIMADA INSTALLATION")
print("="*50)

try:
    import climada
    print("✓ CLIMADA imported successfully")
    #print(f"✓ CLIMADA version: {climada.__version__}")
except ImportError as e:
    print("✗ CLIMADA import failed:", e)

# Test key modules
try:
    from climada.entity import Exposures, ImpactFuncSet, MeasureSet
    print("✓ CLIMADA entity modules imported")
except ImportError as e:
    print("✗ CLIMADA entity import failed:", e)

try:
    from climada.hazard import Hazard
    print("✓ CLIMADA hazard module imported")
except ImportError as e:
    print("✗ CLIMADA hazard import failed:", e)

try:
    from climada.engine import Impact
    print("✓ CLIMADA engine module imported")
except ImportError as e:
    print("✗ CLIMADA engine import failed:", e)

# Test geospatial dependencies
try:
    import geopandas as gpd
    import rasterio
    import fiona
    print("✓ Geospatial libraries imported successfully")
except ImportError as e:
    print("✗ Geospatial libraries import failed:", e)

# =============================================================================
# STEP 3: CLIMADA Configuration
# =============================================================================

# Set up CLIMADA configuration
import os
from pathlib import Path

# Create CLIMADA directories
climada_dir = Path("/content/climada_data")
climada_dir.mkdir(exist_ok=True)
(climada_dir / "hazard").mkdir(exist_ok=True)
(climada_dir / "entity").mkdir(exist_ok=True)
(climada_dir / "results").mkdir(exist_ok=True)

# Set environment variables
os.environ['CLIMADA_DATA'] = str(climada_dir)
print(f"✓ CLIMADA data directory set to: {climada_dir}")

# =============================================================================
# STEP 5: Sample CLIMADA Usage
# =============================================================================

# Simple test to verify everything works
print("\n" + "="*50)
print("RUNNING SAMPLE CLIMADA TEST")
print("="*50)

try:
    # Import required modules
    from climada.entity import Exposures
    from climada.hazard import Hazard
    from climada.hazard.centroids import Centroids
    import numpy as np

    # Create a simple exposure
    # exp = Exposures()
    gdf = gpd.GeoDataFrame({
        'value': [1000, 2000, 3000],
        'geometry': gpd.points_from_xy([1, 2, 3], [1, 2, 3])
    })
    #exp.gdf.crs = 'EPSG:4326'

    exp = Exposures(gdf, crs=4326)

    print("✓ Sample exposure created successfully")
    print(f"✓ Exposure shape: {exp.gdf.shape}")

    centroids = Centroids(lat=np.array([1, 2, 3]), lon=np.array([1, 2, 3]))

    # Create a simple hazard
    haz = Hazard()
    haz.haz_type = 'TC'  # Tropical Cyclone
    haz.description = 'Test hazard'
    haz.centroids = centroids
    #haz.centroids.set_lat_lon(np.array([1, 2, 3]), np.array([1, 2, 3]))
    haz.event_id = np.array([1])
    haz.frequency = np.array([1])
    haz.intensity = np.array([[10, 20, 30]])
    haz.fraction = np.array([[1, 1, 1]])

    print("✓ Sample hazard created successfully")
    print(f"✓ Hazard intensity shape: {haz.intensity.shape}")

    print("\n🎉 CLIMADA installation and setup completed successfully!")

except Exception as e:
    print(f"✗ Sample test failed: {e}")

# =============================================================================
# STEP 6: Useful Helper Functions
# =============================================================================

def setup_climada_session():
    """Run this function at the start of each new Colab session"""
    import os
    from pathlib import Path

    # Recreate directories if needed
    climada_dir = Path("/content/climada_data")
    climada_dir.mkdir(exist_ok=True)
    (climada_dir / "hazard").mkdir(exist_ok=True)
    (climada_dir / "entity").mkdir(exist_ok=True)
    (climada_dir / "results").mkdir(exist_ok=True)

    # Set environment variables
    os.environ['CLIMADA_DATA'] = str(climada_dir)

    print("✓ CLIMADA session setup complete")
    print(f"✓ Data directory: {climada_dir}")

def check_climada_status():
    """Check if CLIMADA is properly installed and configured"""
    try:
        import climada
        from climada.entity import Exposures
        from climada.hazard import Hazard
        from climada.engine import Impact

        print("✓ All CLIMADA modules available")
        print(f"✓ CLIMADA version: {climada.__version__}")
        return True
    except ImportError as e:
        print(f"✗ CLIMADA check failed: {e}")
        return False

# Save helper functions for reuse
print("\n" + "="*50)
print("HELPER FUNCTIONS DEFINED")
print("="*50)
print("Use setup_climada_session() to reinitialize CLIMADA in new sessions")
print("Use check_climada_status() to verify installation")

# =============================================================================
# STEP 7: Save Environment Setup Script
# =============================================================================

# Create a script to quickly reinstall CLIMADA in new sessions

setup_script = '''
# Note: It need to restart and re-run the cell two times to make it fully work

# Quick CLIMADA 6.0.1 Setup Script for Google Colab
# Run this cell in new Colab sessions
# !pip install pandas==2.1.4 fiona==1.10.1 --force-reinstall --no-cache-dir

# *** Restart the session is required after running this cell ***

#Installing condacolab to setup and manage conda environment in colab
# !pip install -q condacolab
import condacolab
condacolab.install()

# *** Restart the session is required after running this cell ***

#Installing climada package
# !mamba install -y -c conda-forge climada==6.0.1

# Checking if proj database file "proj.db" is available in /usr/local/share/proj. Normally, it should be available.
# !ls /usr/local/share/proj/proj.db


#Setting up the environment path so that the packages like pyproj, rasterio, and fiona
#could locate the proj.db without any error/conflict (CRSError: Missing projection database)

import os
os.environ['PROJ_LIB'] = '/usr/local/share/proj'

import climada
from climada.entity import Exposures
from climada.hazard import Hazard
from climada.engine import Impact
print("✓ CLIMADA Package is installed successfully")
'''

with open('/content/quick_climada_setup.py', 'w') as f:
    f.write(setup_script)

print("\n✓ Quick setup script saved to /content/quick_climada_setup.py")
print("✓ Run this script in new Colab sessions for faster setup")

print("\n" + "="*60)
print("🎉 CLIMADA 6.0.1 ENVIRONMENT SETUP COMPLETE!")
print("="*60)
# Out:
# Looking for: ['climada==6.0.1']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.3s
# conda-forge/linux-64   5%
# conda-forge/noarch     3%[+] 0.4s
# conda-forge/linux-64  13%
# conda-forge/noarch    16%[+] 0.5s
# conda-forge/linux-64  26%
# conda-forge/noarch    23%[+] 0.6s
# conda-forge/linux-64  31%
# conda-forge/noarch    34%[+] 0.7s
# conda-forge/linux-64  36%
# conda-forge/noarch    40%[+] 0.8s
# conda-forge/linux-64  39%
# conda-forge/noarch    51%[+] 0.9s
# conda-forge/linux-64  44%
# conda-forge/noarch    63%[+] 1.0s
# conda-forge/linux-64  50%
# conda-forge/noarch    76%[+] 1.1s
# conda-forge/linux-64  55%
# conda-forge/noarch    89%conda-forge/noarch
# [+] 1.2s
# conda-forge/linux-64  61%[+] 1.3s
# conda-forge/linux-64  71%[+] 1.4s
# conda-forge/linux-64  80%[+] 1.5s
# conda-forge/linux-64  90%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - climada==6.0.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                                 Version  Build                    Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + deprecation                             2.1.0  pyh9f0ad1d_0             conda-forge       14kB
#   + unittest-xml-reporting                  3.2.0  pyhd8ed1ab_0             conda-forge       21kB
#   + xlrd                                    2.0.1  pyhd8ed1ab_3             conda-forge       94kB
#   + haversine                               2.9.0  pyhd8ed1ab_0             conda-forge       14kB
#   + pycountry                              24.6.1  pyhd8ed1ab_0             conda-forge        3MB
#   + locket                                  1.0.0  pyhd8ed1ab_0             conda-forge        8kB
#   + click                                   8.2.1  pyh707e725_0             conda-forge       88kB
#   + sortedcontainers                        2.4.0  pyhd8ed1ab_1             conda-forge       29kB
#   + tblib                                   3.1.0  pyhd8ed1ab_0             conda-forge       18kB
#   + toolz                                   1.0.0  pyhd8ed1ab_1             conda-forge       52kB
#   + cloudpickle                             3.1.1  pyhd8ed1ab_0             conda-forge       26kB
#   + zict                                    3.0.0  pyhd8ed1ab_1             conda-forge       36kB
#   + fsspec                               2025.5.1  pyhd8ed1ab_0             conda-forge      146kB
#   + pyshp                                   2.3.1  pyhd8ed1ab_1             conda-forge      427kB
#   + zipp                                   3.23.0  pyhd8ed1ab_0             conda-forge       23kB
#   + nomkl                                     1.0  h5ca1d4c_0               conda-forge        4kB
#   + dill                                    0.4.0  pyhd8ed1ab_0             conda-forge       91kB
#   + pox                                     0.3.6  pyhd8ed1ab_0             conda-forge       27kB
#   + ppft                                    1.7.7  pyhd8ed1ab_0             conda-forge       35kB
#   + pyxlsb                                 1.0.10  pyhd8ed1ab_0             conda-forge       28kB
#   + tabulate                                0.9.0  pyhd8ed1ab_2             conda-forge       38kB
#   + overpy                                    0.7  pyhd8ed1ab_1             conda-forge       20kB
#   + xlsxwriter                              3.2.5  pyhd8ed1ab_0             conda-forge      132kB
#   + attrs                                  25.3.0  pyh71513ae_0             conda-forge       57kB
#   + xyzservices                          2025.4.0  pyhd8ed1ab_0             conda-forge       49kB
#   + narwhals                               1.46.0  pyhe01879c_0             conda-forge      236kB
#   + joblib                                  1.5.1  pyhd8ed1ab_0             conda-forge      224kB
#   + threadpoolctl                           3.6.0  pyhecae5ae_0             conda-forge       24kB
#   + affine                                  2.4.0  pyhd8ed1ab_1             conda-forge       19kB
#   + findlibs                                0.0.5  pyhd8ed1ab_0             conda-forge       13kB
#   + py-cpuinfo                              9.0.0  pyhd8ed1ab_1             conda-forge       26kB
#   + typing_extensions                      4.14.1  pyhe01879c_0             conda-forge       51kB
#   + python-tzdata                          2025.2  pyhd8ed1ab_0             conda-forge      144kB
#   + pytz                                   2025.2  pyhd8ed1ab_0             conda-forge      189kB
#   + et_xmlfile                              2.0.0  pyhd8ed1ab_1             conda-forge       22kB
#   + cycler                                 0.12.1  pyhd8ed1ab_1             conda-forge       13kB
#   + pyparsing                               3.2.3  pyhd8ed1ab_1             conda-forge       96kB
#   + munkres                                 1.1.4  pyhd8ed1ab_1             conda-forge       16kB
#   + six                                    1.17.0  pyhd8ed1ab_0             conda-forge       16kB
#   + cached_property                         1.5.2  pyha770c72_1             conda-forge       11kB
#   + networkx                                  3.5  pyhe01879c_0             conda-forge        2MB
#   + geographiclib                             2.0  pyhd8ed1ab_1             conda-forge       40kB
#   + mercantile                              1.2.1  pyhd8ed1ab_1             conda-forge       20kB
#   + cligj                                   0.7.2  pyhd8ed1ab_2             conda-forge       13kB
#   + click-plugins                         1.1.1.2  pyhd8ed1ab_0             conda-forge       13kB
#   + partd                                   1.4.2  pyhd8ed1ab_0             conda-forge       21kB
#   + importlib-metadata                      8.7.0  pyhe01879c_1             conda-forge       35kB
#   + typing-extensions                      4.14.1  h4440ef1_0               conda-forge       90kB
#   + python-dateutil                   2.9.0.post0  pyhe01879c_2             conda-forge      233kB
#   + cached-property                         1.5.2  hd8ed1ab_1               conda-forge        4kB
#   + geopy                                   2.4.1  pyhd8ed1ab_2             conda-forge       73kB
#   + flexparser                                0.4  pyhd8ed1ab_1             conda-forge       29kB
#   + flexcache                                 0.3  pyhd8ed1ab_1             conda-forge       17kB
#   + pint                                   0.24.4  pyhd8ed1ab_1             conda-forge      230kB
#   + geos                                   3.13.0  h5888daf_0               conda-forge        2MB
#   + icu                                      75.1  he02047a_0               conda-forge       12MB
#   + msgpack-python                          1.1.1  py311hd18a35c_0          conda-forge      103kB
#   + psutil                                  7.0.0  py311h9ecbd09_0          conda-forge      485kB
#   + tornado                                 6.5.1  py311h9ecbd09_0          conda-forge      869kB
#   + lz4                                     4.4.4  py311h8c6ae76_0          conda-forge       40kB
#   + aws-c-common                           0.10.6  hb9d3cd8_0               conda-forge      237kB
#   + libbrotlicommon                         1.1.0  hb9d3cd8_2               conda-forge       69kB
#   + libcrc32c                               1.1.2  h9c3ff4c_0               conda-forge       20kB
#   + libabseil                          20240722.0  cxx17_hbbce691_4         conda-forge        1MB
#   + libopentelemetry-cpp-headers           1.18.0  ha770c72_1               conda-forge      320kB
#   + zlib                                    1.3.1  hb9d3cd8_2               conda-forge       92kB
#   + snappy                                  1.2.1  h8bd8927_1               conda-forge       43kB
#   + gflags                                  2.2.2  h5888daf_1005            conda-forge      120kB
#   + libgfortran5                           14.2.0  hf1ad2bd_2               conda-forge        1MB
#   + libaec                                  1.1.4  h3f801dc_0               conda-forge       37kB
#   + libpng                                 1.6.50  h943b412_0               conda-forge      289kB
#   + markupsafe                              3.0.2  py311h2dc5d0c_1          conda-forge       25kB
#   + giflib                                  5.2.2  hd590300_0               conda-forge       77kB
#   + json-c                                   0.18  h6688a6e_0               conda-forge       83kB
#   + peewee                                 3.17.7  py311h333efcf_0          conda-forge      510kB
#   + zlib-ng                                 2.2.4  h7955e40_0               conda-forge      109kB
#   + libspatialindex                         2.1.0  he57a185_0               conda-forge      399kB
#   + yaml                                    0.2.5  h7f98852_2               conda-forge       89kB
#   + sqlite                                 3.47.2  h9eae976_0               conda-forge      884kB
#   + libjpeg-turbo                           3.1.0  hb9d3cd8_0               conda-forge      629kB
#   + libwebp-base                            1.6.0  hd42ef1d_0               conda-forge      429kB
#   + llvmlite                               0.44.0  py311h9c9ff8c_1          conda-forge       30MB
#   + kiwisolver                              1.4.8  py311hd18a35c_1          conda-forge       74kB
#   + qhull                                  2020.2  h434a139_5               conda-forge      553kB
#   + pthread-stubs                             0.4  hb9d3cd8_1002            conda-forge        8kB
#   + xorg-libxdmcp                           1.1.5  hb9d3cd8_0               conda-forge       20kB
#   + xorg-libxau                            1.0.12  hb9d3cd8_0               conda-forge       15kB
#   + lerc                                    4.0.0  h0aef613_1               conda-forge      264kB
#   + nlohmann_json                          3.12.0  h3f2d84a_0               conda-forge      136kB
#   + uriparser                               0.9.8  hac33072_0               conda-forge       48kB
#   + aom                                     3.9.1  hac33072_0               conda-forge        3MB
#   + dav1d                                   1.2.1  hd590300_0               conda-forge      760kB
#   + libde265                               1.0.15  h00ab1b0_0               conda-forge      412kB
#   + unicodedata2                           16.0.0  py311h9ecbd09_0          conda-forge      405kB
#   + x265                                      3.5  h924138e_3               conda-forge        3MB
#   + rav1e                                   0.7.1  h8fae777_3               conda-forge        5MB
#   + svt-av1                                 3.0.2  h5888daf_0               conda-forge        3MB
#   + libglvnd                                1.7.0  ha4b6fd6_2               conda-forge      132kB
#   + libdeflate                               1.23  h86f0d12_0               conda-forge       73kB
#   + pcre2                                   10.44  hc749103_2               conda-forge      956kB
#   + libutf8proc                            2.10.0  h202a827_0               conda-forge       83kB
#   + cytoolz                                 1.0.1  py311h9ecbd09_0          conda-forge      394kB
#   + multiprocess                          0.70.18  py311h9ecbd09_0          conda-forge      352kB
#   + openpyxl                                3.1.5  py311h50c5138_1          conda-forge      708kB
#   + librttopo                               1.1.0  h97f6797_17              conda-forge      232kB
#   + xerces-c                                3.2.5  h988505b_2               conda-forge        2MB
#   + aws-c-compression                       0.3.0  h4e1184b_5               conda-forge       19kB
#   + aws-c-sdkutils                          0.2.2  h4e1184b_0               conda-forge       56kB
#   + aws-checksums                           0.2.2  h4e1184b_4               conda-forge       73kB
#   + libbrotlienc                            1.1.0  hb9d3cd8_2               conda-forge      282kB
#   + libbrotlidec                            1.1.0  hb9d3cd8_2               conda-forge       33kB
#   + libre2-11                          2024.07.02  hbbce691_2               conda-forge      210kB
#   + libprotobuf                            5.28.3  h6128344_1               conda-forge        3MB
#   + prometheus-cpp                          1.3.0  ha5d0236_0               conda-forge      200kB
#   + blosc                                  1.21.6  he440d0b_1               conda-forge       48kB
#   + glog                                    0.7.1  hbabe93e_0               conda-forge      143kB
#   + libgfortran                            14.2.0  h69a702a_2               conda-forge       54kB
#   + libfreetype6                           2.13.3  h48d6fc4_1               conda-forge      380kB
#   + c-blosc2                               2.16.0  h3122c55_0               conda-forge      343kB
#   + rtree                                   1.3.0  py311h0181012_3          conda-forge       71kB
#   + pyyaml                                  6.0.2  py311h2dc5d0c_2          conda-forge      213kB
#   + hdf4                                   4.2.15  h2a13503_7               conda-forge      757kB
#   + libxcb                                 1.17.0  h8a09558_0               conda-forge      396kB
#   + libkml                                  1.3.0  hf539b9f_1021            conda-forge      402kB
#   + libavif16                               1.3.0  h766b0b6_0               conda-forge      140kB
#   + libopengl                               1.7.0  ha4b6fd6_2               conda-forge       51kB
#   + libtiff                                 4.7.0  hd9ff511_3               conda-forge      428kB
#   + minizip                                 4.0.7  h05a5f5f_3               conda-forge       92kB
#   + libevent                               2.1.12  hf998b51_1               conda-forge      427kB
#   + s2n                                    1.5.11  h072c03f_0               conda-forge      356kB
#   + libzip                                 1.11.2  h6991a6a_0               conda-forge      109kB
#   + aws-c-cal                               0.8.1  h1a47875_3               conda-forge       48kB
#   + azure-core-cpp                         1.14.0  h5cfcd09_0               conda-forge      345kB
#   + libxslt                                1.1.39  h76b75d6_0               conda-forge      254kB
#   + brotli-bin                              1.1.0  hb9d3cd8_2               conda-forge       19kB
#   + re2                                2024.07.02  h9925aae_2               conda-forge       27kB
#   + orc                                     2.0.3  h12ee42a_2               conda-forge        1MB
#   + libopenblas                            0.3.29  pthreads_h94d23a6_0      conda-forge        6MB
#   + hdf5                                   1.14.3  nompi_h2d575fe_109       conda-forge        4MB
#   + libfreetype                            2.13.3  ha770c72_1               conda-forge        8kB
#   + xorg-libx11                            1.8.12  h4f16b4b_0               conda-forge      836kB
#   + libheif                                1.19.7  gpl_hc18d805_100         conda-forge      597kB
#   + libglu                                  9.0.3  h5888daf_1               conda-forge      325kB
#   + openjpeg                                2.5.3  h5fbd93e_0               conda-forge      343kB
#   + lcms2                                    2.17  h717163a_0               conda-forge      248kB
#   + proj                                    9.5.1  h0054346_0               conda-forge        3MB
#   + freexl                                  2.0.0  h9dce30a_2               conda-forge       59kB
#   + libthrift                              0.21.0  h0e7cc3e_0               conda-forge      426kB
#   + aws-c-io                               0.15.3  h173a860_6               conda-forge      157kB
#   + azure-storage-common-cpp               12.8.0  h736e048_1               conda-forge      149kB
#   + azure-identity-cpp                     1.10.0  h113e628_0               conda-forge      232kB
#   + lxml                                    5.3.1  py311hcfaa980_0          conda-forge        1MB
#   + brotli                                  1.1.0  hb9d3cd8_2               conda-forge       19kB
#   + libgrpc                                1.67.1  h25350d4_2               conda-forge        8MB
#   + libblas                                 3.9.0  31_h59b9bed_openblas     conda-forge       17kB
#   + libnetcdf                               4.9.2  nompi_h00e09a9_116       conda-forge      835kB
#   + freetype                               2.13.3  ha770c72_1               conda-forge      172kB
#   + xorg-libxfixes                          6.0.1  hb9d3cd8_0               conda-forge       20kB
#   + xorg-libxext                            1.3.6  hb9d3cd8_0               conda-forge       50kB
#   + geotiff                                 1.7.4  h3551947_0               conda-forge      129kB
#   + pyproj                                  3.7.1  py311h0f98d5a_0          conda-forge      563kB
#   + libspatialite                           5.1.0  h1b4f908_12              conda-forge        4MB
#   + aws-c-http                              0.9.2  hefd7a92_4               conda-forge      198kB
#   + aws-c-event-stream                      0.5.0  h7959bf6_11              conda-forge       54kB
#   + azure-storage-blobs-cpp               12.13.0  h3cf044e_1               conda-forge      549kB
#   + fonttools                              4.58.5  py311h2dc5d0c_0          conda-forge        3MB
#   + libopentelemetry-cpp                   1.18.0  hfcad708_1               conda-forge      802kB
#   + libgoogle-cloud                        2.35.0  h2b5623c_0               conda-forge        1MB
#   + libcblas                                3.9.0  31_he106b2a_openblas     conda-forge       17kB
#   + liblapack                               3.9.0  31_h7ac8fdf_openblas     conda-forge       17kB
#   + pillow                                 10.4.0  py311h4aec55e_1          conda-forge       42MB
#   + xorg-libxi                              1.8.2  hb9d3cd8_0               conda-forge       47kB
#   + libgdal-core                           3.10.1  h3359108_0               conda-forge       11MB
#   + aws-c-mqtt                             0.11.0  h11f4f37_12              conda-forge      195kB
#   + aws-c-auth                              0.8.1  h205f482_0               conda-forge      108kB
#   + azure-storage-files-datalake-cpp      12.12.0  ha633028_1               conda-forge      287kB
#   + libgoogle-cloud-storage                2.35.0  h0121fbd_0               conda-forge      786kB
#   + numpy                                  1.26.4  py311h64a7726_0          conda-forge        8MB
#   + freeglut                                3.2.2  ha6d2627_3               conda-forge      144kB
#   + aws-c-s3                                0.7.9  he1b24dc_1               conda-forge      115kB
#   + cftime                                  1.6.4  py311h9f3472d_1          conda-forge      250kB
#   + contourpy                               1.3.2  py311hd18a35c_0          conda-forge      278kB
#   + scipy                                  1.14.1  py311he9a78e4_2          conda-forge       18MB
#   + numexpr                                2.10.2  py311h38b10cd_100        conda-forge      201kB
#   + numba                                  0.61.2  py311h9806782_1          conda-forge        6MB
#   + h5py                                   3.12.1  nompi_py311hb639ac4_103  conda-forge        1MB
#   + gdal                                   3.10.1  py311hbde30c8_2          conda-forge        2MB
#   + bottleneck                              1.4.2  py311h9f3472d_0          conda-forge      144kB
#   + shapely                                 2.0.7  py311h2fdb869_0          conda-forge      581kB
#   + pandas                                  2.1.4  py311h320fe9a_0          conda-forge       15MB
#   + jasper                                  4.2.5  h1920b20_0               conda-forge      688kB
#   + aws-crt-cpp                            0.29.9  he0e7f3f_2               conda-forge      353kB
#   + netcdf4                                 1.7.2  nompi_py311hae66bec_101  conda-forge        1MB
#   + matplotlib-base                        3.10.3  py311h2b939e6_0          conda-forge        8MB
#   + scikit-learn                            1.6.1  py311h57cc02b_0          conda-forge       11MB
#   + pytables                               3.10.2  py311h6d53d72_1          conda-forge        2MB
#   + fiona                                  1.10.1  py311hf6089d3_3          conda-forge        1MB
#   + eccodes                                2.40.0  h8bb6dbc_0               conda-forge        5MB
#   + aws-sdk-cpp                          1.11.489  h4d475cb_0               conda-forge        3MB
#   + cartopy                                0.24.0  py311h7db5c69_0          conda-forge        2MB
#   + python-eccodes                         2.37.0  py311h9f3472d_0          conda-forge      107kB
#   + libarrow                               19.0.1  hfa2a6e7_0_cpu           conda-forge        9MB
#   + libarrow-acero                         19.0.1  hcb10f89_0_cpu           conda-forge      638kB
#   + libparquet                             19.0.1  h081d1f1_0_cpu           conda-forge        1MB
#   + pyarrow-core                           19.0.1  py311h4854187_0_cpu      conda-forge        5MB
#   + libarrow-dataset                       19.0.1  hcb10f89_0_cpu           conda-forge      604kB
#   + libarrow-substrait                     19.0.1  h08228c5_0_cpu           conda-forge      523kB
#   + pyarrow                                19.0.1  py311h38be061_0          conda-forge       25kB
#   + jinja2                                  3.1.6  pyhd8ed1ab_0             conda-forge      113kB
#   + pathos                                  0.3.4  pyhd8ed1ab_0             conda-forge       53kB
#   + dask-core                            2025.2.0  pyhd8ed1ab_0             conda-forge      968kB
#   + snuggs                                  1.4.7  pyhd8ed1ab_2             conda-forge       11kB
#   + patsy                                   1.0.1  pyhd8ed1ab_1             conda-forge      187kB
#   + sparse                                 0.15.5  pyh72ffeb9_0             conda-forge       98kB
#   + xarray                               2025.1.2  pyhd8ed1ab_0             conda-forge      838kB
#   + geopandas-base                         0.14.4  pyha770c72_0             conda-forge        1MB
#   + pandas-datareader                      0.10.0  pyhd8ed1ab_1             conda-forge       76kB
#   + seaborn-base                           0.13.2  pyhd8ed1ab_3             conda-forge      228kB
#   + mapclassify                             2.9.0  pyhd8ed1ab_0             conda-forge      277kB
#   + bayesian-optimization                   1.5.1  pyhd8ed1ab_1             conda-forge       31kB
#   + branca                                  0.8.1  pyhd8ed1ab_0             conda-forge       30kB
#   + bokeh                                   3.7.3  pyhd8ed1ab_0             conda-forge        5MB
#   + salib                                   1.5.1  pyhd8ed1ab_0             conda-forge      664kB
#   + distributed                          2025.2.0  pyhd8ed1ab_0             conda-forge      800kB
#   + cfgrib                               0.9.15.0  pyhd8ed1ab_0             conda-forge       43kB
#   + folium                                 0.20.0  pyhd8ed1ab_0             conda-forge       83kB
#   + dask                                 2025.2.0  pyhd8ed1ab_0             conda-forge        8kB
#   + geopandas                              0.14.4  pyhd8ed1ab_0             conda-forge        8kB
#   + osm-flex                                1.1.1  pyhd8ed1ab_1             conda-forge       38kB
#   + rasterio                                1.4.3  py311h5394301_0          conda-forge        8MB
#   + statsmodels                            0.14.5  py311hb0beb2c_0          conda-forge       12MB
#   + contextily                              1.6.2  pyhd8ed1ab_1             conda-forge       21kB
#   + seaborn                                0.13.2  hd8ed1ab_3               conda-forge        7kB
#   + climada                                 6.0.1  pyhd8ed1ab_0             conda-forge       14MB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - libxml2                                2.13.5  h0d44e9d_1               conda-forge     Cached
#   + libxml2                                2.13.5  h8d12d68_1               conda-forge      691kB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates                    2024.12.14  hbcca054_0               conda-forge     Cached
#   + ca-certificates                      2025.7.9  hbd8a1cb_0               conda-forge      152kB
#   - certifi                            2024.12.14  pyhd8ed1ab_0             conda-forge     Cached
#   + certifi                              2025.7.9  pyhd8ed1ab_0             conda-forge      157kB
#   - openssl                                 3.4.0  h7b32b05_1               conda-forge     Cached
#   + openssl                                 3.5.1  h7b32b05_0               conda-forge        3MB
#
#   Summary:
#
#   Install: 234 packages
#   Change: 1 packages
#   Upgrade: 3 packages
#
#   Total download: 335MB
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%deprecation                                         14.5kB @ 125.0kB/s  0.1s
# haversine                                           13.7kB @  97.1kB/s  0.1s
# locket                                               8.2kB @  47.4kB/s  0.1s
# unittest-xml-reporting                              21.1kB @ 120.4kB/s  0.2s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (4)  ⣾  xlrd                                                94.1kB @ 469.9kB/s  0.2s
# click                                               87.7kB @ 358.4kB/s  0.1s
# toolz                                               52.5kB @ 213.6kB/s  0.1s
# nomkl                                                3.8kB @  13.4kB/s  0.1s
# cloudpickle                                         25.9kB @  89.4kB/s  0.1s
# pyxlsb                                              28.3kB @  97.2kB/s  0.0s
# [+] 0.3s
# Downloading  (5)   1%
# Extracting   (8)  ⣾  pycountry                                            3.1MB @   8.6MB/s  0.4s
# ppft                                                34.9kB @  97.3kB/s  0.1s
# py-cpuinfo                                          25.8kB @  71.7kB/s  0.1s
# xyzservices                                         49.5kB @ 131.2kB/s  0.1s
# [+] 0.4s
# Downloading  (5)   2%
# Extracting  (10)  ⣾  narwhals                                           236.1kB @ 567.8kB/s  0.1s
# pytz                                               189.0kB @ 449.5kB/s  0.1s
# et_xmlfile                                          21.9kB @  51.6kB/s  0.1s
# cycler                                              13.4kB @  31.3kB/s  0.1s
# mercantile                                          19.7kB @  45.4kB/s  0.1s
# partd                                               20.9kB @  43.8kB/s  0.1s
# python-dateutil                                    233.3kB @ 487.9kB/s  0.1s
# [+] 0.5s
# Downloading  (5)   2%
# Extracting  (16)  ⣾  flexparser                                          28.7kB @  53.5kB/s  0.1s
# libbrotlicommon                                     68.9kB @ 128.1kB/s  0.1s
# aws-c-common                                       236.6kB @ 433.4kB/s  0.1s
# psutil                                             484.8kB @ 829.4kB/s  0.2s
# snappy                                              42.7kB @  72.3kB/s  0.1s
# [+] 0.6s
# Downloading  (5)   2%
# Extracting  (19)  ⣾  giflib                                              77.2kB @ 128.9kB/s  0.1s
# gflags                                             119.7kB @ 197.8kB/s  0.1s
# sqlite                                             884.4kB @   1.3MB/s  0.1s
# zlib-ng                                            108.8kB @ 164.5kB/s  0.1s
# pthread-stubs                                        8.3kB @  12.4kB/s  0.1s
# [+] 0.7s
# Downloading  (5)   3%
# Extracting  (23)  ⣾  lerc                                               264.2kB @ 368.8kB/s  0.1s
# geos                                                 1.9MB @   2.4MB/s  0.3s
# unicodedata2                                       405.0kB @ 527.2kB/s  0.1s
# [+] 0.8s
# Downloading  (5)   4%
# Extracting  (26)  ⣾  svt-av1                                              2.8MB @   3.4MB/s  0.1s
# aom                                                  2.7MB @   3.3MB/s  0.2s
# libutf8proc                                         83.1kB @  94.0kB/s  0.1s
# pcre2                                              956.2kB @   1.1MB/s  0.1s
# [+] 0.9s
# Downloading  (5)   6%
# Extracting  (28)  ⣾  aws-c-compression                                   19.1kB @  20.6kB/s  0.1s
# librttopo                                          231.8kB @ 247.7kB/s  0.1s
# libbrotlienc                                       281.8kB @ 283.6kB/s  0.1s
# c-blosc2                                           343.5kB @ 345.2kB/s  0.1s
# [+] 1.0s
# Downloading  (5)   9%
# Extracting  (29)  ⣾  libprotobuf                                          3.0MB @   3.0MB/s  0.1s
# glog                                               143.5kB @ 141.0kB/s  0.1s
# libxcb                                             395.9kB @ 380.5kB/s  0.0s
# minizip                                             92.3kB @  88.1kB/s  0.0s
# libzip                                             109.0kB @  99.8kB/s  0.1s
# [+] 1.1s
# Downloading  (5)  11%
# Extracting  (33)  ⣾  hdf4                                               756.7kB @ 671.3kB/s  0.1s
# libxslt                                            254.3kB @ 225.6kB/s  0.1s
# orc                                                  1.2MB @   1.0MB/s  0.1s
# libfreetype                                          7.7kB @   6.6kB/s  0.1s
# aws-c-io                                           157.3kB @ 132.6kB/s  0.1s
# [+] 1.2s
# Downloading  (5)  14%
# Extracting  (38)  ⣾  libglu                                             325.3kB @ 271.3kB/s  0.1s
# openjpeg                                           343.0kB @ 276.0kB/s  0.1s
# lxml                                                 1.4MB @   1.1MB/s  0.1s
# xorg-libxfixes                                      19.6kB @  15.6kB/s  0.1s
# libblas                                             16.9kB @  13.3kB/s  0.1s
# [+] 1.3s
# Downloading  (5)  16%
# Extracting  (43)  ⣾  azure-storage-blobs-cpp                            549.3kB @ 418.4kB/s  0.1s
# liblapack                                           16.8kB @  12.7kB/s  0.1s
# aws-c-event-stream                                  54.0kB @  39.2kB/s  0.1s
# azure-storage-files-datalake-cpp                   287.4kB @ 208.5kB/s  0.1s
# pyproj                                             562.8kB @ 407.7kB/s  0.1s
# llvmlite                                            30.0MB @  21.7MB/s  0.8s
# [+] 1.4s
# Downloading  (5)  17%
# Extracting  (47)  ⣾  aws-c-s3                                           115.4kB @  80.4kB/s  0.1s
# freeglut                                           144.0kB @ 100.2kB/s  0.1s
# bottleneck                                         143.7kB @  99.9kB/s  0.1s
# [+] 1.5s
# Downloading  (5)  18%
# Extracting  (48)  ⣾  jasper                                             688.3kB @ 452.2kB/s  0.1s
# numba                                                6.0MB @   3.8MB/s  0.2s
# [+] 1.6s
# Downloading  (5)  21%
# Extracting  (50)  ⣾  cartopy                                              1.5MB @ 934.9kB/s  0.1s
# libarrow-acero                                     638.1kB @ 380.9kB/s  0.1s
# [+] 1.7s
# Downloading  (5)  25%
# Extracting  (52)  ⣾  jinja2                                             112.7kB @  65.4kB/s  0.0s
# [+] 1.8s
# Downloading  (8)  27%
# Extracting  (52)  ⣾  scikit-learn                                        10.7MB @   6.0MB/s  0.4s
# libarrow-dataset                                   604.5kB @ 337.8kB/s  0.2s
# snuggs                                              11.3kB @   6.3kB/s  0.1s
# pandas-datareader                                   76.1kB @  40.8kB/s  0.1s
# xarray                                             838.0kB @ 445.6kB/s  0.1s
# libgdal-core                                        10.8MB @   5.7MB/s  0.6s
# [+] 1.9s
# Downloading  (5)  29%
# Extracting  (57)  ⣾  matplotlib-base                                      8.3MB @   4.4MB/s  0.5s
# geopandas-base                                       1.0MB @ 533.5kB/s  0.1s
# dask                                                 7.6kB @   3.9kB/s  0.1s
# seaborn                                              6.9kB @   3.5kB/s  0.1s
# certifi                                            156.7kB @  78.7kB/s  0.1s
# [+] 2.0s
# Downloading  (5)  30%
# Extracting  (62)  ⣾  zict                                                36.3kB @  18.1kB/s  0.1s
# dill                                                90.9kB @  44.3kB/s  0.1s
# rasterio                                             7.6MB @   3.7MB/s  0.2s
# attrs                                               57.2kB @  27.3kB/s  0.1s
# [+] 2.1s
# Downloading  (5)  32%
# Extracting  (65)  ⣾  zipp                                                23.0kB @  10.9kB/s  0.1s
# distributed                                        800.3kB @ 380.2kB/s  0.2s
# affine                                              19.2kB @   9.1kB/s  0.1s
# python-tzdata                                      144.2kB @  68.0kB/s  0.0s
# six                                                 16.4kB @   7.6kB/s  0.1s
# importlib-metadata                                  34.6kB @  16.0kB/s  0.1s
# geopy                                               73.0kB @  33.5kB/s  0.1s
# [+] 2.2s
# Downloading  (5)  33%
# Extracting  (72)  ⣾  libopentelemetry-cpp-headers                       320.4kB @ 144.4kB/s  0.1s
# lz4                                                 40.1kB @  18.1kB/s  0.1s
# geographiclib                                       39.9kB @  17.9kB/s  0.1s
# json-c                                              82.7kB @  36.5kB/s  0.1s
# libaec                                              36.8kB @  16.2kB/s  0.1s
# [+] 2.3s
# Downloading  (5)  34%
# Extracting  (76)  ⣾  xorg-libxau                                         14.8kB @   6.4kB/s  0.0s
# icu                                                 12.1MB @   5.2MB/s  0.2s
# dav1d                                              760.2kB @ 325.2kB/s  0.1s
# peewee                                             510.1kB @ 218.1kB/s  0.1s
# [+] 2.4s
# Downloading  (5)  37%
# Extracting  (79)  ⣾  kiwisolver                                          73.7kB @  30.6kB/s  0.2s
# openpyxl                                           708.0kB @ 287.9kB/s  0.1s
# xerces-c                                             1.6MB @ 665.1kB/s  0.1s
# openssl                                              3.1MB @   1.3MB/s  0.2s
# [+] 2.5s
# Downloading  (5)  38%
# Extracting  (82)  ⣾  rav1e                                                5.2MB @   2.1MB/s  0.2s
# libgfortran                                         53.7kB @  21.4kB/s  0.0s
# libre2-11                                          209.8kB @  82.9kB/s  0.1s
# libopengl                                           50.8kB @  20.0kB/s  0.0s
# pyyaml                                             213.1kB @  83.4kB/s  0.1s
# brotli-bin                                          18.9kB @   7.4kB/s  0.1s
# [+] 2.6s
# Downloading  (5)  40%
# Extracting  (86)  ⣾  lcms2                                              248.0kB @  95.7kB/s  0.1s
# brotli                                              19.3kB @   7.3kB/s  0.1s
# s2n                                                356.2kB @ 135.4kB/s  0.1s
# freetype                                           172.4kB @  65.3kB/s  0.0s
# libthrift                                          425.8kB @ 161.2kB/s  0.1s
# hdf5                                                 3.9MB @   1.5MB/s  0.1s
# xorg-libxext                                        50.1kB @  18.7kB/s  0.1s
# [+] 2.7s
# Downloading  (5)  42%
# Extracting  (92)  ⣾  xorg-libxi                                          47.2kB @  17.4kB/s  0.1s
# cftime                                             249.9kB @  91.9kB/s  0.1s
# numexpr                                            200.6kB @  73.3kB/s  0.1s
# fonttools                                            2.9MB @   1.1MB/s  0.1s
# [+] 2.8s
# Downloading  (5)  43%
# Extracting  (95)  ⣾  shapely                                            580.6kB @ 207.9kB/s  0.1s
# netcdf4                                              1.2MB @ 407.6kB/s  0.1s
# [+] 2.9s
# Downloading  (5)  46%
# Extracting  (96)  ⣾  libarrow-substrait                                 523.3kB @ 180.8kB/s  0.1s
# eccodes                                              4.7MB @   1.6MB/s  0.2s
# branca                                              29.6kB @   9.9kB/s  0.1s
# dask-core                                          968.3kB @ 324.1kB/s  0.2s
# seaborn-base                                       227.8kB @  76.3kB/s  0.1s
# [+] 3.0s
# Downloading  (5)  50%
# Extracting  (98)  ⣾  libarrow                                             9.0MB @   3.0MB/s  0.3s
# geopandas                                            7.7kB @   2.5kB/s  0.1s
# folium                                              82.7kB @  27.0kB/s  0.1s
# cfgrib                                              43.5kB @  14.2kB/s  0.1s
# [+] 3.1s
# Downloading  (5)   54%
# Extracting  (104)  ⣾  tblib                                               17.9kB @   5.7kB/s  0.1s
# xlsxwriter                                         131.9kB @  42.2kB/s  0.1s
# findlibs                                            12.6kB @   4.0kB/s  0.1s
# munkres                                             15.9kB @   5.0kB/s  0.1s
# pox                                                 27.3kB @   8.6kB/s  0.1s
# cligj                                               12.5kB @   3.9kB/s  0.1s
# [+] 3.2s
# Downloading  (5)   55%
# Extracting  (109)  ⣾  cached-property                                      4.1kB @   1.3kB/s  0.1s
# msgpack-python                                     103.1kB @  31.9kB/s  0.1s
# yaml                                                89.1kB @  27.3kB/s  0.1s
# zlib                                                92.3kB @  28.2kB/s  0.1s
# libabseil                                            1.3MB @ 398.2kB/s  0.1s
# [+] 3.3s
# Downloading  (5)   57%
# Extracting  (113)  ⣾  libjpeg-turbo                                      628.9kB @ 189.2kB/s  0.1s
# libglvnd                                           132.5kB @  39.3kB/s  0.1s
# uriparser                                           48.3kB @  14.3kB/s  0.1s
# multiprocess                                       351.9kB @ 104.2kB/s  0.1s
# [+] 3.4s
# Downloading  (5)   59%
# Extracting  (117)  ⣾  aws-checksums                                       72.8kB @  21.2kB/s  0.1s
# blosc                                               48.4kB @  14.1kB/s  0.1s
# libfreetype6                                       380.1kB @ 110.6kB/s  0.1s
# pillow                                              42.3MB @  12.3MB/s  0.8s
# rtree                                               71.1kB @  20.5kB/s  0.1s
# [+] 3.5s
# Downloading  (5)   61%
# Extracting  (121)  ⣾  re2                                                 26.8kB @   7.6kB/s  0.1s
# azure-storage-common-cpp                           149.3kB @  42.4kB/s  0.1s
# aws-c-http                                         197.7kB @  56.1kB/s  0.1s
# libheif                                            596.7kB @ 169.1kB/s  0.1s
# libnetcdf                                          834.9kB @ 236.6kB/s  0.1s
# [+] 3.6s
# Downloading  (5)   62%
# Extracting  (126)  ⣾  aws-c-mqtt                                         194.7kB @  54.0kB/s  0.1s
# libcblas                                            16.8kB @   4.7kB/s  0.1s
# fiona                                                1.2MB @ 326.0kB/s  0.1s
# [+] 3.7s
# Downloading  (5)   65%
# Extracting  (128)  ⣾  pathos                                              53.3kB @  14.4kB/s  0.1s
# mapclassify                                        276.8kB @  74.7kB/s  0.1s
# libparquet                                           1.2MB @ 330.3kB/s  0.2s
# numpy                                                8.1MB @   2.1MB/s  0.3s
# [+] 3.8s
# Downloading  (5)   67%
# Extracting  (131)  ⣾  sortedcontainers                                    28.7kB @   7.5kB/s  0.1s
# salib                                              664.1kB @ 172.9kB/s  0.1s
# osm-flex                                            38.4kB @  10.0kB/s  0.1s
# fsspec                                             145.5kB @  37.8kB/s  0.1s
# [+] 3.9s
# Downloading  (5)   70%
# Extracting  (134)  ⣾  threadpoolctl                                       23.9kB @   6.1kB/s  0.1s
# cached_property                                     11.1kB @   2.8kB/s  0.1s
# click-plugins                                       12.7kB @   3.2kB/s  0.1s
# pandas                                              15.0MB @   3.8MB/s  0.4s
# networkx                                             1.6MB @ 392.9kB/s  0.1s
# libcrc32c                                           20.4kB @   5.1kB/s  0.1s
# [+] 4.0s
# Downloading  (6)   70%
# Extracting  (138)  ⣾  libspatialindex                                    399.2kB @ 100.0kB/s  0.1s
# libdeflate                                          72.8kB @  18.2kB/s  0.1s
# nlohmann_json                                      135.9kB @  33.9kB/s  0.1s
# freexl                                              59.3kB @  14.5kB/s  0.1s
# [+] 4.1s
# Downloading  (4)   71%
# Extracting  (142)  ⣾  cytoolz                                            394.2kB @  96.4kB/s  0.1s
# libevent                                           427.4kB @ 104.2kB/s  0.1s
# libxml2                                            690.6kB @ 168.3kB/s  0.2s
# geotiff                                            129.4kB @  31.1kB/s  0.1s
# [+] 4.2s
# Downloading  (5)   71%
# Extracting  (145)  ⣾  libopentelemetry-cpp                               801.9kB @ 191.0kB/s  0.1s
# pyarrow                                             25.3kB @   5.9kB/s  0.1s
# gdal                                                 1.7MB @ 405.7kB/s  0.1s
# libspatialite                                        4.0MB @ 942.1kB/s  0.2s
# [+] 4.3s
# Downloading  (5)   75%
# Extracting  (147)  ⣾  contextily                                          20.7kB @   4.8kB/s  0.1s
# aws-sdk-cpp                                          3.1MB @ 721.2kB/s  0.2s
# bayesian-optimization                               30.6kB @   7.0kB/s  0.1s
# pyshp                                              427.4kB @  97.8kB/s  0.1s
# libopenblas                                          5.9MB @   1.4MB/s  0.4s
# [+] 4.4s
# Downloading  (5)   76%
# Extracting  (152)  ⣾  pyparsing                                           96.0kB @  21.7kB/s  0.1s
# joblib                                             224.4kB @  50.8kB/s  0.1s
# markupsafe                                          25.4kB @   5.7kB/s  0.1s
# typing_extensions                                   51.1kB @  11.5kB/s  0.1s
# libwebp-base                                       429.0kB @  96.5kB/s  0.1s
# [+] 4.5s
# Downloading  (5)   76%
# Extracting  (155)  ⣾  aws-c-sdkutils                                      55.9kB @  12.5kB/s  0.1s
# libbrotlidec                                        32.7kB @   7.3kB/s  0.1s
# aws-c-cal                                           47.6kB @  10.5kB/s  0.1s
# libgoogle-cloud                                      1.3MB @ 277.5kB/s  0.1s
# proj                                                 3.1MB @ 683.8kB/s  0.1s
# ca-certificates                                    152.4kB @  33.2kB/s  0.0s
# [+] 4.6s
# Downloading  (5)   78%
# Extracting  (160)  ⣾  contourpy                                          278.4kB @  60.7kB/s  0.1s
# typing-extensions                                   90.5kB @  19.4kB/s  0.1s
# [+] 4.7s
# Downloading  (5)   79%
# Extracting  (162)  ⣾  [+] 4.8s
# Downloading  (5)   80%
# Extracting  (162)  ⣾  [+] 4.9s
# Downloading  (5)   80%
# Extracting  (162)  ⣾  [+] 5.0s
# Downloading  (5)   80%
# Extracting  (162)  ⣾  [+] 5.1s
# Downloading  (5)   80%
# Extracting  (162)  ⣾  tornado                                            869.3kB @ 169.4kB/s  0.5s
# qhull                                              552.9kB @ 107.5kB/s  0.5s
# pytables                                             1.7MB @ 330.3kB/s  0.6s
# [+] 5.2s
# Downloading  (5)   82%
# Extracting  (165)  ⣾  libavif16                                          140.1kB @  26.9kB/s  0.1s
# bokeh                                                4.9MB @ 948.3kB/s  0.7s
# libtiff                                            428.2kB @  82.0kB/s  0.1s
# aws-c-auth                                         108.1kB @  20.6kB/s  0.1s
# x265                                                 3.4MB @ 638.5kB/s  0.1s
# aws-crt-cpp                                        353.2kB @  66.8kB/s  0.1s
# patsy                                              186.6kB @  35.2kB/s  0.1s
# [+] 5.3s
# Downloading  (5)   85%
# Extracting  (171)  ⣾  tabulate                                            37.6kB @   7.1kB/s  0.1s
# xorg-libx11                                        835.9kB @ 155.0kB/s  0.1s
# [+] 5.4s
# Downloading  (4)   86%
# Extracting  (172)  ⣾  libpng                                             289.2kB @  53.3kB/s  0.1s
# libgoogle-cloud-storage                            785.8kB @ 144.2kB/s  0.1s
# prometheus-cpp                                     199.5kB @  36.6kB/s  0.2s
# [+] 5.5s
# Downloading  (5)   88%
# Extracting  (176)  ⣾  overpy                                              19.9kB @   3.6kB/s  0.1s
# scipy                                               17.7MB @   3.2MB/s  1.0s
# pyarrow-core                                         4.7MB @ 848.4kB/s  0.2s
# [+] 5.6s
# Downloading  (5)   91%
# Extracting  (179)  ⣾  azure-core-cpp                                     345.1kB @  61.5kB/s  0.1s
# libgfortran5                                         1.5MB @ 260.3kB/s  0.2s
# sparse                                              98.5kB @  17.5kB/s  0.1s
# libkml                                             402.2kB @  71.1kB/s  0.1s
# [+] 5.7s
# Downloading  (5)   93%
# Extracting  (182)  ⣾  python-eccodes                                     106.7kB @  18.6kB/s  0.1s
# pint                                               230.2kB @  40.2kB/s  0.1s
# xorg-libxdmcp                                       19.9kB @   3.5kB/s  0.1s
# libde265                                           411.8kB @  71.8kB/s  0.1s
# climada                                             14.5MB @   2.5MB/s  0.5s
# azure-identity-cpp                                 232.4kB @  40.1kB/s  0.1s
# [+] 5.8s
# Downloading  (4)   94%
# Extracting  (187)  ⣾  h5py                                                 1.4MB @ 240.4kB/s  0.1s
# flexcache                                           16.7kB @   2.9kB/s  0.1s
# [+] 5.9s
# Downloading  (2)   96%
# Extracting  (190)  ⣾  libgrpc                                              8.2MB @   1.4MB/s  0.2s
# [+] 6.0s
# Downloading  (1)   99%
# Extracting  (189)  ⣾  statsmodels                                         12.0MB @   2.0MB/s  0.4s
# [+] 6.1s
# Downloading       100%
# Extracting  (190)  ⣾  [+] 6.2s
# Downloading       100%
# Extracting  (188)  ⣾  [+] 6.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 6.4s
# Downloading       100%
# Extracting  (186)  ⣾  [+] 6.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 6.6s
# Downloading       100%
# Extracting  (184)  ⣾  [+] 6.7s
# Downloading       100%
# Extracting  (184)  ⣾  [+] 6.8s
# Downloading       100%
# Extracting  (183)  ⣾  [+] 6.9s
# Downloading       100%
# Extracting  (183)  ⣾  [+] 7.0s
# Downloading       100%
# Extracting  (182)  ⣾  [+] 7.1s
# Downloading       100%
# Extracting  (182)  ⣾  [+] 7.2s
# Downloading       100%
# Extracting  (181)  ⣾  [+] 7.3s
# Downloading       100%
# Extracting  (181)  ⣾  [+] 7.4s
# Downloading       100%
# Extracting  (180)  ⣾  [+] 7.5s
# Downloading       100%
# Extracting  (180)  ⣾  [+] 7.6s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 7.7s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 7.8s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 7.9s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 8.0s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 8.1s
# Downloading       100%
# Extracting  (178)  ⣾  [+] 8.2s
# Downloading       100%
# Extracting  (178)  ⣾  [+] 8.3s
# Downloading       100%
# Extracting  (176)  ⣾  [+] 8.4s
# Downloading       100%
# Extracting  (176)  ⣾  [+] 8.5s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 8.6s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 8.7s
# Downloading       100%
# Extracting  (173)  ⣾  [+] 8.8s
# Downloading       100%
# Extracting  (171)  ⣾  [+] 8.9s
# Downloading       100%
# Extracting  (171)  ⣾  [+] 9.0s
# Downloading       100%
# Extracting  (170)  ⣾  [+] 9.1s
# Downloading       100%
# Extracting  (170)  ⣾  [+] 9.2s
# Downloading       100%
# Extracting  (169)  ⣾  [+] 9.3s
# Downloading       100%
# Extracting  (168)  ⣾  [+] 9.4s
# Downloading       100%
# Extracting  (168)  ⣾  [+] 9.5s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 9.6s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 9.7s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 9.8s
# Downloading       100%
# Extracting  (165)  ⣾  [+] 9.9s
# Downloading       100%
# Extracting  (164)  ⣾  [+] 10.0s
# Downloading       100%
# Extracting  (164)  ⣾  [+] 10.1s
# Downloading       100%
# Extracting  (162)  ⣾  [+] 10.2s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 10.3s
# Downloading       100%
# Extracting  (160)  ⣾  [+] 10.4s
# Downloading       100%
# Extracting  (158)  ⣾  [+] 10.5s
# Downloading       100%
# Extracting  (156)  ⣾  [+] 10.6s
# Downloading       100%
# Extracting  (155)  ⣾  [+] 10.7s
# Downloading       100%
# Extracting  (153)  ⣾  [+] 10.8s
# Downloading       100%
# Extracting  (152)  ⣾  [+] 10.9s
# Downloading       100%
# Extracting  (150)  ⣾  [+] 11.0s
# Downloading       100%
# Extracting  (148)  ⣾  [+] 11.1s
# Downloading       100%
# Extracting  (146)  ⣾  [+] 11.2s
# Downloading       100%
# Extracting  (145)  ⣾  [+] 11.3s
# Downloading       100%
# Extracting  (144)  ⣾  [+] 11.4s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 11.5s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 11.6s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 11.7s
# Downloading       100%
# Extracting  (139)  ⣾  [+] 11.8s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 11.9s
# Downloading       100%
# Extracting  (137)  ⣾  [+] 12.0s
# Downloading       100%
# Extracting  (135)  ⣾  [+] 12.1s
# Downloading       100%
# Extracting  (135)  ⣾  [+] 12.2s
# Downloading       100%
# Extracting  (134)  ⣾  [+] 12.3s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 12.4s
# Downloading       100%
# Extracting  (132)  ⣾  [+] 12.5s
# Downloading       100%
# Extracting  (131)  ⣾  [+] 12.6s
# Downloading       100%
# Extracting  (130)  ⣾  [+] 12.7s
# Downloading       100%
# Extracting  (129)  ⣾  [+] 12.8s
# Downloading       100%
# Extracting  (129)  ⣾  [+] 12.9s
# Downloading       100%
# Extracting  (129)  ⣾  [+] 13.0s
# Downloading       100%
# Extracting  (129)  ⣾  [+] 13.1s
# Downloading       100%
# Extracting  (128)  ⣾  [+] 13.2s
# Downloading       100%
# Extracting  (127)  ⣾  [+] 13.3s
# Downloading       100%
# Extracting  (127)  ⣾  [+] 13.4s
# Downloading       100%
# Extracting  (126)  ⣾  [+] 13.5s
# Downloading       100%
# Extracting  (125)  ⣾  [+] 13.6s
# Downloading       100%
# Extracting  (123)  ⣾  [+] 13.7s
# Downloading       100%
# Extracting  (123)  ⣾  [+] 13.8s
# Downloading       100%
# Extracting  (122)  ⣾  [+] 13.9s
# Downloading       100%
# Extracting  (120)  ⣾  [+] 14.0s
# Downloading       100%
# Extracting  (119)  ⣾  [+] 14.1s
# Downloading       100%
# Extracting  (117)  ⣾  [+] 14.2s
# Downloading       100%
# Extracting  (116)  ⣾  [+] 14.3s
# Downloading       100%
# Extracting  (115)  ⣾  [+] 14.4s
# Downloading       100%
# Extracting  (115)  ⣾  [+] 14.5s
# Downloading       100%
# Extracting  (114)  ⣾  [+] 14.6s
# Downloading       100%
# Extracting  (114)  ⣾  [+] 14.7s
# Downloading       100%
# Extracting  (113)  ⣾  [+] 14.8s
# Downloading       100%
# Extracting  (113)  ⣾  [+] 14.9s
# Downloading       100%
# Extracting  (112)  ⣾  [+] 15.0s
# Downloading       100%
# Extracting  (112)  ⣾  [+] 15.1s
# Downloading       100%
# Extracting  (111)  ⣾  [+] 15.2s
# Downloading       100%
# Extracting  (111)  ⣾  [+] 15.3s
# Downloading       100%
# Extracting  (110)  ⣾  [+] 15.4s
# Downloading       100%
# Extracting  (110)  ⣾  [+] 15.5s
# Downloading       100%
# Extracting  (110)  ⣾  [+] 15.6s
# Downloading       100%
# Extracting  (109)  ⣾  [+] 15.7s
# Downloading       100%
# Extracting  (109)  ⣾  [+] 15.8s
# Downloading       100%
# Extracting  (108)  ⣾  [+] 15.9s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 16.0s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 16.1s
# Downloading       100%
# Extracting  (105)  ⣾  [+] 16.2s
# Downloading       100%
# Extracting  (104)  ⣾  [+] 16.3s
# Downloading       100%
# Extracting  (102)  ⣾  [+] 16.4s
# Downloading       100%
# Extracting  (101)  ⣾  [+] 16.5s
# Downloading       100%
# Extracting  (100)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting  (99)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting  (98)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting  (97)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting  (94)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting  (92)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting  (90)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting  (88)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting  (86)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting  (82)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.5s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.6s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.7s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.8s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 25.9s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 26.0s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 26.1s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 26.2s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 26.3s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 26.4s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 26.5s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 26.6s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 26.7s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 26.8s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 26.9s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 27.0s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 27.1s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 27.2s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 27.3s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 27.4s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 27.5s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 27.6s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 27.7s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 27.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 27.9s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 28.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 28.1s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 28.2s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 28.3s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 28.4s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 28.5s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 28.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 28.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 28.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
# /usr/local/share/proj/proj.db
# ✓ CLIMADA 6.0.1 installed using official requirements
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
#
# ==================================================
# TESTING CLIMADA INSTALLATION
# ==================================================
# ✓ CLIMADA imported successfully
# ✓ CLIMADA entity modules imported
# ✓ CLIMADA hazard module imported
# ✓ CLIMADA engine module imported
# ✓ Geospatial libraries imported successfully
# ✓ CLIMADA data directory set to: /content/climada_data
#
# ==================================================
# RUNNING SAMPLE CLIMADA TEST
# ==================================================
# ✓ Sample exposure created successfully
# ✓ Exposure shape: (3, 2)
# ✓ Sample hazard created successfully
# ✓ Hazard intensity shape: (1, 3)
#
# 🎉 CLIMADA installation and setup completed successfully!
#
# ==================================================
# HELPER FUNCTIONS DEFINED
# ==================================================
# Use setup_climada_session() to reinitialize CLIMADA in new sessions
# Use check_climada_status() to verify installation
#
# ✓ Quick setup script saved to /content/quick_climada_setup.py
# ✓ Run this script in new Colab sessions for faster setup
#
# ============================================================
# 🎉 CLIMADA 6.0.1 ENVIRONMENT SETUP COMPLETE!
# ============================================================
